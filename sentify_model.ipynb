# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import scipy as sp
import json
from sklearn import preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from chunkdot import CosineSimilarityTopK
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from textblob import TextBlob
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from langdetect import detect

# %% [markdown]
# ## Import challenge data

# %%
# Load JSON data from file
with open('data/challenge_set.json', 'r') as file: # Replace with local dataset path
    data = json.load(file)

# Initialize an empty list to collect all track data
all_tracks = []

# Loop through each playlist in the dataset
for playlist in data['playlists']:
    for track in playlist['tracks']:
        # Add playlist-level information to each track record
        track_info = {
            'playlist_name': playlist.get('name', 'Unknown'),
            'playlist_pid': playlist['pid'],
            'playlist_num_tracks': playlist['num_tracks'],
            'track_pos': track['pos'],
            'artist_name': track['artist_name'],
            'track_uri': track['track_uri'],
            'artist_uri': track['artist_uri'],
            'track_name': track['track_name'],
            'album_uri': track['album_uri'],
            'duration_ms': track['duration_ms'],
            'album_name': track['album_name']
        }
        all_tracks.append(track_info)

# Convert the list of track dictionaries to a DataFrame
df_spotify = pd.DataFrame(all_tracks)

# %% [markdown]
# ## Import and clean additional data

# %% [markdown]
# ### Import and clean lyrics

# %%
# Import lyrics
df_lyrics = pd.read_csv('data/lyrics.csv')

# Detect language for every lyric in df_lyrics
detected_languages = [detect(text) for text in df_lyrics['lyrics']]

# Append the list of detected languages to the DataFrame as a new column
df_lyrics['lan_lyrics'] = detected_languages

# Drop rows with lyrics that are not in english (3449 non english lyrics)
index_lyrics = df_lyrics[ (df_lyrics['lan_lyrics'] != 'en')].index
df_lyrics.drop(index_lyrics , inplace=True)

# Remove lyrics that are no lyrics
rows_to_remove = str("abcdefghijklmnopqrst|by year: |the notorious b.i.g.'s songs|highest to lowest|total:")

# Drop rows with incorrect lyrics (2126 incorrect lyrics)
index_remove = df_lyrics.loc[df_lyrics.lyrics.str.contains(rows_to_remove),:].index
df_lyrics.drop(index_remove , inplace=True)

# %% [markdown]
# ### Create and build word vectors for lyrics

# %%
#Link: https://www.kaggle.com/code/zeeshanlatif/countvectorizer-vs-tfidfvectorizer

# Removing stopwords from the data
stop_words = stopwords.words("english")
df_lyrics['lyrics'] = df_lyrics['lyrics'].apply(lambda x: " ".join(word for word in x.split() if word not in stop_words))

# applying lemmatization
wnl = WordNetLemmatizer()
df_lyrics['lyrics'] = df_lyrics['lyrics'].apply(lambda x: " ".join(wnl.lemmatize(word) for word in x.split()))

# %% [markdown]
# ### Create sentiment scores with Vader

# %%
# Initialize the VADER sentiment intensity analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get the compound sentiment score
def get_sentiment(text):
    score = analyzer.polarity_scores(text)
    return score['compound']  # Return the compound score

# Apply the sentiment analysis function to the cleaned lyrics
df_lyrics['vader_sentiment_score'] = df_lyrics['lyrics'].apply(get_sentiment)


def assign_sentiment(score):
    if score > 0.05:
        return 'positive'
    elif score < -0.05:
        return 'negative'
    else:
        return 'neutral'

# Apply sentiment label assignment
df_lyrics['vader_sentiment_label'] = df_lyrics['vader_sentiment_score'].apply(assign_sentiment)

# %% [markdown]
# ### Create sentiment scores with Textblob

# %%
def get_tb(text):
    text = TextBlob(text)
    return text.sentiment.polarity

# Apply the sentiment analysis function to the cleaned lyrics
df_lyrics['tb_sentiment_score'] = df_lyrics['lyrics'].apply(get_tb)

def assign_sentiment(score):
    if score > 0.05:
        return 'positive'
    elif score < -0.05:
        return 'negative'
    else:
        return 'neutral'

# Apply sentiment label assignment
df_lyrics['tb_sentiment_label'] = df_lyrics['tb_sentiment_score'].apply(assign_sentiment)

# %% [markdown]
# ### Combine lyrics and original data set

# %%
df_spotify = df_spotify.merge(df_lyrics, on='track_uri', how='left')

# After the merge there are 22322 rows without lyrics which are removed here
df_spotify.dropna(inplace=True)

# %% [markdown]
# ### Import genre data

# %%
df_genres = pd.read_csv('data/dummy_encoded_genres.csv')
#df_genres.drop(labels='Unnamed: 0', axis=1, inplace=True)

# %%
# Drop genre columns with fewer than 3 occurrences
genre_columns = df_genres.columns.drop('artist_uri')
columns_to_drop = [col for col in genre_columns if df_genres[col].sum() < 8]

df_genres = df_genres.drop(columns=columns_to_drop)

# %%
# Merge genre with the rest
df_spotify = df_spotify.merge(df_genres, on='artist_uri', how='left')

# %%
df_spotify[df_spotify['artist_name']=='Evanescence'][['track_uri', 'track_name', 'artist_name','vader_sentiment_score']]
# Out:
#                                    track_uri
# 4677    spotify:track:1C0vXECyJHUeqOo2Etvrr2  \
# 13160   spotify:track:0tWEB6BxbI48XN79QE1JbT
# 14241   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 14242   spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 14243   spotify:track:663Karu2rvKLdnY0eo1n3M
# 32766   spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 44125   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 61227   spotify:track:663Karu2rvKLdnY0eo1n3M
# 61703   spotify:track:0a5IY60a8Ejwjdi1RIqpbh
# 62618   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 64034   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 67051   spotify:track:7vdaUubsjqxTOepM1qtTPx
# 67052   spotify:track:2GlZWLkp0Ta38PLDa8gWVI
# 67053   spotify:track:08OwfYvHvEEdfUCFx2LDav
# 67054   spotify:track:01eDuNCOaqDXpWltABQq2f
# 76710   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 76711   spotify:track:0a5IY60a8Ejwjdi1RIqpbh
# 84671   spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 96706   spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 101644  spotify:track:2bik1YtthlwTawpcrfQJbO
# 101654  spotify:track:1tk7WJcqJ8BPfsanK7HuK4
# 126004  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 126550  spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 131963  spotify:track:4HSOUsVciyKpao5p5xeGVq
# 145622  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 147449  spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 147450  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 162349  spotify:track:663Karu2rvKLdnY0eo1n3M
# 170822  spotify:track:663Karu2rvKLdnY0eo1n3M
# 170823  spotify:track:6l65sisDuqcCNzLYTK9GpR
# 170824  spotify:track:4iDQezFTnOwgnrPYiqQ6TP
# 174467  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 185567  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 204436  spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 204437  spotify:track:663Karu2rvKLdnY0eo1n3M
# 210384  spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 216396  spotify:track:0tWEB6BxbI48XN79QE1JbT
# 216397  spotify:track:6U4FxcxHp1CpjWe4S46dPu
# 232653  spotify:track:663Karu2rvKLdnY0eo1n3M
# 243219  spotify:track:1C0vXECyJHUeqOo2Etvrr2
# 246231  spotify:track:07EeNeSCYJajyJW5U7Q3Wd
# 246232  spotify:track:663Karu2rvKLdnY0eo1n3M
#
#                                            track_name  artist_name
# 4677                                      My Immortal  Evanescence  \
# 13160                                Everybody's Fool  Evanescence
# 14241                                     My Immortal  Evanescence
# 14242                                     Going Under  Evanescence
# 14243                       Call Me When You're Sober  Evanescence
# 32766                                     Going Under  Evanescence
# 44125                                     My Immortal  Evanescence
# 61227                       Call Me When You're Sober  Evanescence
# 61703                                           Hello  Evanescence
# 62618                                     My Immortal  Evanescence
# 64034                                     My Immortal  Evanescence
# 67051                                  The Other Side  Evanescence
# 67052                                            Sick  Evanescence
# 67053                                          Oceans  Evanescence
# 67054                              A New Way To Bleed  Evanescence
# 76710                                     My Immortal  Evanescence
# 76711                                           Hello  Evanescence
# 84671                                     My Immortal  Evanescence
# 96706                                     Going Under  Evanescence
# 101644  Thoughtless - Live From Le Zénith,France/2004  Evanescence
# 101654                                  What You Want  Evanescence
# 126004                                    My Immortal  Evanescence
# 126550                                    Going Under  Evanescence
# 131963                             My Heart Is Broken  Evanescence
# 145622                                    My Immortal  Evanescence
# 147449                                    Going Under  Evanescence
# 147450                                    My Immortal  Evanescence
# 162349                      Call Me When You're Sober  Evanescence
# 170822                      Call Me When You're Sober  Evanescence
# 170823                               Snow White Queen  Evanescence
# 170824                       All That I Am Living For  Evanescence
# 174467                                    My Immortal  Evanescence
# 185567                                    My Immortal  Evanescence
# 204436                                    Going Under  Evanescence
# 204437                      Call Me When You're Sober  Evanescence
# 210384                                    Going Under  Evanescence
# 216396                               Everybody's Fool  Evanescence
# 216397                                      Imaginary  Evanescence
# 232653                      Call Me When You're Sober  Evanescence
# 243219                                    My Immortal  Evanescence
# 246231                                    Going Under  Evanescence
# 246232                      Call Me When You're Sober  Evanescence
#
#         vader_sentiment_score
# 4677                  -0.9838
# 13160                  0.8886
# 14241                 -0.9838
# 14242                 -0.9480
# 14243                 -0.9216
# 32766                 -0.9480
# 44125                 -0.9838
# 61227                 -0.9216
# 61703                  0.7791
# 62618                 -0.9838
# 64034                 -0.9838
# 67051                  0.8531
# 67052                 -0.9968
# 67053                  0.9229
# 67054                  0.9896
# 76710                 -0.9838
# 76711                  0.7791
# 84671                 -0.9838
# 96706                 -0.9480
# 101644                -0.9964
# 101654                -0.8619
# 126004                -0.9838
# 126550                -0.9480
# 131963                 0.8880
# 145622                -0.9838
# 147449                -0.9480
# 147450                -0.9838
# 162349                -0.9216
# 170822                -0.9216
# 170823                 0.4660
# 170824                 0.9273
# 174467                -0.9838
# 185567                -0.9838
# 204436                -0.9480
# 204437                -0.9216
# 210384                -0.9480
# 216396                 0.8886
# 216397                -0.7246
# 232653                -0.9216
# 243219                -0.9838
# 246231                -0.9480
# 246232                -0.9216

# %% [markdown]
# ## Create cosine similarity model

# %% [markdown]
# ### Drop unwanted features

# %%
drop_list = ['playlist_name', 'playlist_num_tracks', 'artist_name', 'album_uri', 'track_uri', 'duration_ms', 'track_pos',
             'track_name', 'album_name', 'lyrics', 'lan_lyrics', 'tb_sentiment_score', 'vader_sentiment_label', 'tb_sentiment_label'] 

#After investigating both Vader & Textblob we discovered that Vader catches the sentiment better than tb. TB tends to be very neutral most of the times. Therefore we drop tb scores here
#You can play around with the different features just unlist them from the drop_list

# %%
df_spotify_pipeline = df_spotify.drop(columns=drop_list)

# %% [markdown]
# ### Set up pipline

# %%
#numeric_features = ['duration_ms']
categorical_features = ['artist_uri', 'playlist_pid']

#numeric_transformer = Pipeline(steps=[("scaler", StandardScaler())])
categorical_transformer = Pipeline(steps=[("encoder", OneHotEncoder())])

preprocessor = ColumnTransformer(
    transformers=[
        #("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features),
    ]
)

cos_sim = CosineSimilarityTopK(top_k=50)

cos_sim_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("cos_sim", cos_sim)])

cos_sim_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder())]),
#                                                   ['artist_uri',
#                                                    'playlist_pid'])])),
#                 ('cos_sim', CosineSimilarityTopK(top_k=50))])

# %% [markdown]
# ### Compute cosine similarity matrix

# %%
# Compute cos_sim matrix
sim_matrix = cos_sim_pipeline.fit_transform(df_spotify_pipeline)

# Convert csr.matrix to Dataframe
sim_matrix_df = pd.DataFrame.sparse.from_spmatrix(sim_matrix)

# %%
# code for exporting/storing the cos sim matrix
# code from here: https://stackoverflow.com/questions/75158465/saving-large-sparse-arrays-in-hdf5-using-pickle

# Save the sparse similarity matrix as an npz file for sentify
sp.sparse.save_npz('models/sentify.npz', sim_matrix) # documentation: https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.save_npz.html

# %%
#Store the data as a pickle file for Sentify
df_spotify.to_pickle('data/sentify.pkl')
