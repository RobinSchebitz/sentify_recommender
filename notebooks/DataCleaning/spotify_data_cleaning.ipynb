# %% [markdown]
# # Data Cleaning Process for Lyrics API

# %%
import pandas as pd
import numpy as np
import json
import re

# %%
spotify = pd.read_csv('spotify_data.csv')
spotify.head()
# Out:
#                               track_uri artist_name
# 0  spotify:track:66U0ASk1VHZsqIkpMjKX3B   AronChupa  \
# 1  spotify:track:5MhsZlmKJG6X5kTHkdwC4B   AronChupa
# 2  spotify:track:0GZoB8h0kqXn7XFm4Sj06k       Lorde
# 3  spotify:track:35kahykNu00FPysz3C2euR       Lorde
# 4  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1       Lorde
#
#                                           track_name
# 0                                       Little Swing
# 1                                   I'm an Albatraoz
# 2  Yellow Flicker Beat - From The Hunger Games: M...
# 3                                  White Teeth Teens
# 4                                               Team

# %%
spotify.shape
# Out:
# (66228, 3)

# %%
null_values = spotify[spotify['artist_name'].isna() | spotify['track_name'].isna()]

# %%
null_values.head(100)
# Out:
#                                   track_uri        artist_name track_name
# 1261   spotify:track:4uzLUC10GP0m11MP72gPEr                NaN        NaN
# 2733   spotify:track:1C79CxJdMHjk9RkwX04DRh                NaN        NaN
# 5383   spotify:track:128zElW4z27JtpfRKPkJwF                NaN        NaN
# 5386   spotify:track:3lpnYiJSFZmtsIM13OyRfa                NaN        NaN
# 8151   spotify:track:6l4qV9VNeCOesvcLPJMO9y                NaN        NaN
# 11156  spotify:track:1lROXJjQxzq35Zswlk96sO                NaN        NaN
# 11157  spotify:track:3WMYZuHiVSJkP6NpcDhYrL                NaN        NaN
# 11158  spotify:track:5KEhTPcoLJxZShVi30SEWQ                NaN        NaN
# 11159  spotify:track:6x17ndQcCsRwla1aXyepvF                NaN        NaN
# 14511  spotify:track:41AioelS7TlDckavuvL4fs                NaN        NaN
# 17440  spotify:track:4MJlgdrGLaayCTPtdn0kII                NaN        NaN
# 17442  spotify:track:3sQyifoaayj7MUTMxb5TjH                NaN        NaN
# 22327  spotify:track:0lMrWcrVXHPEuVBuc0nRzZ                NaN        NaN
# 25339  spotify:track:3FhuPkzBM6VMLvc6rcer8v                NaN        NaN
# 26813  spotify:track:49sc9cNZvWKiI5TgPvhulE                NaN        NaN
# 35020  spotify:track:1WGiezPGli6yE3cm87xyVW                NaN        NaN
# 38251  spotify:track:4YhITuwINLCfXYB2WCXbCZ                NaN        NaN
# 41309  spotify:track:0mby3QJBZ5k4XDuds8dDyE                NaN        NaN
# 44537  spotify:track:34E9hD7Pu65I2T29SJWxxa                NaN        NaN
# 44697  spotify:track:4t6HLZizcQiD8IvKUQU8il                NaN        NaN
# 47467  spotify:track:2k50oK27Gqmdv6tpOSYj4z                NaN        NaN
# 48916  spotify:track:5BInskLvwqz56ClUpfqdI4                NaN        NaN
# 51314  spotify:track:7HqxdIaQIututlNzxt6jJX                NaN        NaN
# 56410  spotify:track:75sQOid9BjI4pbw5GT3EmY                NaN        NaN
# 56412  spotify:track:7jczFX9ZGyUBtMKAcmUmwI                NaN        NaN
# 65696  spotify:track:0V2bvR5Uaq89RkB23w9Zl2                NaN        NaN
# 65961  spotify:track:7BGQCe62A58Q5ZgpQFX93t  Elevation Worship        NaN

# %%
# Insert a track name where 'none' got misinterpreted as NaN
null_values.loc[65961, 'track_name'] = 'None'
# Out:
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_8176/3509439607.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_values.loc[65961, 'track_name'] = 'None'

# %%
null_values
# Out:
#                                   track_uri        artist_name track_name
# 1261   spotify:track:4uzLUC10GP0m11MP72gPEr                NaN        NaN
# 2733   spotify:track:1C79CxJdMHjk9RkwX04DRh                NaN        NaN
# 5383   spotify:track:128zElW4z27JtpfRKPkJwF                NaN        NaN
# 5386   spotify:track:3lpnYiJSFZmtsIM13OyRfa                NaN        NaN
# 8151   spotify:track:6l4qV9VNeCOesvcLPJMO9y                NaN        NaN
# 11156  spotify:track:1lROXJjQxzq35Zswlk96sO                NaN        NaN
# 11157  spotify:track:3WMYZuHiVSJkP6NpcDhYrL                NaN        NaN
# 11158  spotify:track:5KEhTPcoLJxZShVi30SEWQ                NaN        NaN
# 11159  spotify:track:6x17ndQcCsRwla1aXyepvF                NaN        NaN
# 14511  spotify:track:41AioelS7TlDckavuvL4fs                NaN        NaN
# 17440  spotify:track:4MJlgdrGLaayCTPtdn0kII                NaN        NaN
# 17442  spotify:track:3sQyifoaayj7MUTMxb5TjH                NaN        NaN
# 22327  spotify:track:0lMrWcrVXHPEuVBuc0nRzZ                NaN        NaN
# 25339  spotify:track:3FhuPkzBM6VMLvc6rcer8v                NaN        NaN
# 26813  spotify:track:49sc9cNZvWKiI5TgPvhulE                NaN        NaN
# 35020  spotify:track:1WGiezPGli6yE3cm87xyVW                NaN        NaN
# 38251  spotify:track:4YhITuwINLCfXYB2WCXbCZ                NaN        NaN
# 41309  spotify:track:0mby3QJBZ5k4XDuds8dDyE                NaN        NaN
# 44537  spotify:track:34E9hD7Pu65I2T29SJWxxa                NaN        NaN
# 44697  spotify:track:4t6HLZizcQiD8IvKUQU8il                NaN        NaN
# 47467  spotify:track:2k50oK27Gqmdv6tpOSYj4z                NaN        NaN
# 48916  spotify:track:5BInskLvwqz56ClUpfqdI4                NaN        NaN
# 51314  spotify:track:7HqxdIaQIututlNzxt6jJX                NaN        NaN
# 56410  spotify:track:75sQOid9BjI4pbw5GT3EmY                NaN        NaN
# 56412  spotify:track:7jczFX9ZGyUBtMKAcmUmwI                NaN        NaN
# 65696  spotify:track:0V2bvR5Uaq89RkB23w9Zl2                NaN        NaN
# 65961  spotify:track:7BGQCe62A58Q5ZgpQFX93t  Elevation Worship       None

# %%
# Load JSON data from file
with open('data/challenge_set.json', 'r') as file: # Replace with local dataset path
    data = json.load(file)

# Initialize an empty list to collect all track data
all_tracks = []

# Loop through each playlist in the dataset
for playlist in data['playlists']:
    for track in playlist['tracks']:
        # Add playlist-level information to each track record
        track_info = {
            'playlist_name': playlist.get('name', 'Unknown'),
            'playlist_pid': playlist['pid'],
            'playlist_num_tracks': playlist['num_tracks'],
            'track_pos': track['pos'],
            'artist_name': track['artist_name'],
            'track_uri': track['track_uri'],
            'artist_uri': track['artist_uri'],
            'track_name': track['track_name'],
            'album_uri': track['album_uri'],
            'duration_ms': track['duration_ms'],
            'album_name': track['album_name']
        }
        all_tracks.append(track_info)

# Convert the list of track dictionaries to a DataFrame
df_spotify = pd.DataFrame(all_tracks)

# Display the first few rows of the DataFrame to verify
print(df_spotify.head())
# Out:
#   playlist_name  playlist_pid  playlist_num_tracks  track_pos artist_name
# 0         Party       1000000                   75          0   AronChupa  \
# 1         Party       1000000                   75          1   AronChupa
# 2         Party       1000000                   75          2       Lorde
# 3         Party       1000000                   75          3       Lorde
# 4         Party       1000000                   75          4       Lorde
#
#                               track_uri
# 0  spotify:track:66U0ASk1VHZsqIkpMjKX3B  \
# 1  spotify:track:5MhsZlmKJG6X5kTHkdwC4B
# 2  spotify:track:0GZoB8h0kqXn7XFm4Sj06k
# 3  spotify:track:35kahykNu00FPysz3C2euR
# 4  spotify:track:3G6hD9B2ZHOsgf4WfNu7X1
#
#                               artist_uri
# 0  spotify:artist:5vCOdeiQt9LyzdI87kt5Sh  \
# 1  spotify:artist:5vCOdeiQt9LyzdI87kt5Sh
# 2  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 3  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
# 4  spotify:artist:163tK9Wjr9P9DmM0AVK7lm
#
#                                           track_name
# 0                                       Little Swing  \
# 1                                   I'm an Albatraoz
# 2  Yellow Flicker Beat - From The Hunger Games: M...
# 3                                  White Teeth Teens
# 4                                               Team
#
#                               album_uri  duration_ms           album_name
# 0  spotify:album:4S5MLjwRSi0NJ5nikflYnZ       163809         Little Swing
# 1  spotify:album:1qHVYbxQ6IS8YRviorKDJI       166848     I'm an Albatraoz
# 2  spotify:album:4UEPxQx0cTcYNsE0n32MHV       232506  Yellow Flicker Beat
# 3  spotify:album:0rmhjUgoVa17LZuS8xWQ3v       216600         Pure Heroine
# 4  spotify:album:0rmhjUgoVa17LZuS8xWQ3v       193058         Pure Heroine

# %%
# Creating new dataset for getting lyrics of unique songs
df_spotify = df_spotify.drop_duplicates(subset=['track_uri']).drop(['playlist_name', 'playlist_pid', 'playlist_num_tracks', 'track_pos',
       'artist_uri', 'album_uri', 'duration_ms', 'album_name'], axis=1).reset_index(drop=True)

# %%
df_spotify = df_spotify[['track_uri', 'artist_name', 'track_name']]

# %%
null_values
# Out:
#                                   track_uri        artist_name track_name
# 1261   spotify:track:4uzLUC10GP0m11MP72gPEr                NaN        NaN
# 2733   spotify:track:1C79CxJdMHjk9RkwX04DRh                NaN        NaN
# 5383   spotify:track:128zElW4z27JtpfRKPkJwF                NaN        NaN
# 5386   spotify:track:3lpnYiJSFZmtsIM13OyRfa                NaN        NaN
# 8151   spotify:track:6l4qV9VNeCOesvcLPJMO9y                NaN        NaN
# 11156  spotify:track:1lROXJjQxzq35Zswlk96sO                NaN        NaN
# 11157  spotify:track:3WMYZuHiVSJkP6NpcDhYrL                NaN        NaN
# 11158  spotify:track:5KEhTPcoLJxZShVi30SEWQ                NaN        NaN
# 11159  spotify:track:6x17ndQcCsRwla1aXyepvF                NaN        NaN
# 14511  spotify:track:41AioelS7TlDckavuvL4fs                NaN        NaN
# 17440  spotify:track:4MJlgdrGLaayCTPtdn0kII                NaN        NaN
# 17442  spotify:track:3sQyifoaayj7MUTMxb5TjH                NaN        NaN
# 22327  spotify:track:0lMrWcrVXHPEuVBuc0nRzZ                NaN        NaN
# 25339  spotify:track:3FhuPkzBM6VMLvc6rcer8v                NaN        NaN
# 26813  spotify:track:49sc9cNZvWKiI5TgPvhulE                NaN        NaN
# 35020  spotify:track:1WGiezPGli6yE3cm87xyVW                NaN        NaN
# 38251  spotify:track:4YhITuwINLCfXYB2WCXbCZ                NaN        NaN
# 41309  spotify:track:0mby3QJBZ5k4XDuds8dDyE                NaN        NaN
# 44537  spotify:track:34E9hD7Pu65I2T29SJWxxa                NaN        NaN
# 44697  spotify:track:4t6HLZizcQiD8IvKUQU8il                NaN        NaN
# 47467  spotify:track:2k50oK27Gqmdv6tpOSYj4z                NaN        NaN
# 48916  spotify:track:5BInskLvwqz56ClUpfqdI4                NaN        NaN
# 51314  spotify:track:7HqxdIaQIututlNzxt6jJX                NaN        NaN
# 56410  spotify:track:75sQOid9BjI4pbw5GT3EmY                NaN        NaN
# 56412  spotify:track:7jczFX9ZGyUBtMKAcmUmwI                NaN        NaN
# 65696  spotify:track:0V2bvR5Uaq89RkB23w9Zl2                NaN        NaN
# 65961  spotify:track:7BGQCe62A58Q5ZgpQFX93t  Elevation Worship       None

# %%
# Merge the dataframes on 'track_uri'
merged_df = null_values.merge(df_spotify, on='track_uri', suffixes=('_null', '_spotify'), how='left')

# Now you can select the relevant columns if needed
result_df = merged_df[['track_uri', 'artist_name_spotify', 'track_name_spotify']]
# Out:
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_8176/3397326678.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_values['artist_name'] = merged_df['artist_name_spotify']
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_8176/3397326678.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   null_values['track_name'] = merged_df['track_name_spotify']

# %%
merged_df.drop(columns = ['track_name_null', 'artist_name_null'], inplace=True)

# %%
merged_df.rename(columns={'artist_name_spotify' : 'artist_name', 'track_name_spotify' : 'track_name'}, inplace=True)

# %%
merged_df
# Out:
#                                track_uri                        artist_name
# 0   spotify:track:4uzLUC10GP0m11MP72gPEr                          Lady Gaga  \
# 1   spotify:track:1C79CxJdMHjk9RkwX04DRh                          Lady Gaga
# 2   spotify:track:128zElW4z27JtpfRKPkJwF                         Brian Tuey
# 3   spotify:track:3lpnYiJSFZmtsIM13OyRfa                         Brian Tuey
# 4   spotify:track:6l4qV9VNeCOesvcLPJMO9y                         Chief Keef
# 5   spotify:track:1lROXJjQxzq35Zswlk96sO  Julión Álvarez y su Norteño Banda
# 6   spotify:track:3WMYZuHiVSJkP6NpcDhYrL  Julión Álvarez y su Norteño Banda
# 7   spotify:track:5KEhTPcoLJxZShVi30SEWQ  Julión Álvarez y su Norteño Banda
# 8   spotify:track:6x17ndQcCsRwla1aXyepvF  Julión Álvarez y su Norteño Banda
# 9   spotify:track:41AioelS7TlDckavuvL4fs                    Tariq Da Hustla
# 10  spotify:track:4MJlgdrGLaayCTPtdn0kII                          Lady Gaga
# 11  spotify:track:3sQyifoaayj7MUTMxb5TjH                          Lady Gaga
# 12  spotify:track:0lMrWcrVXHPEuVBuc0nRzZ                        Alan Walker
# 13  spotify:track:3FhuPkzBM6VMLvc6rcer8v  Julión Álvarez y su Norteño Banda
# 14  spotify:track:49sc9cNZvWKiI5TgPvhulE                       Thoomas Jack
# 15  spotify:track:1WGiezPGli6yE3cm87xyVW                          Lady Gaga
# 16  spotify:track:4YhITuwINLCfXYB2WCXbCZ                        Alan Walker
# 17  spotify:track:0mby3QJBZ5k4XDuds8dDyE                          Lady Gaga
# 18  spotify:track:34E9hD7Pu65I2T29SJWxxa                     Cameron Dallas
# 19  spotify:track:4t6HLZizcQiD8IvKUQU8il                          Lady Gaga
# 20  spotify:track:2k50oK27Gqmdv6tpOSYj4z                         Atif Aslam
# 21  spotify:track:5BInskLvwqz56ClUpfqdI4                              Trapt
# 22  spotify:track:7HqxdIaQIututlNzxt6jJX                     Peter Frampton
# 23  spotify:track:75sQOid9BjI4pbw5GT3EmY                          Lady Gaga
# 24  spotify:track:7jczFX9ZGyUBtMKAcmUmwI                          Lady Gaga
# 25  spotify:track:0V2bvR5Uaq89RkB23w9Zl2  Julión Álvarez y su Norteño Banda
# 26  spotify:track:7BGQCe62A58Q5ZgpQFX93t                  Elevation Worship
#
#                    track_name
# 0                        Dope
# 1                    Applause
# 2        Lullaby Of A Deadman
# 3                         115
# 4                      Faneto
# 5          El Amor De Su Vida
# 6             Eso Si Me Dolió
# 7                 El Aferrado
# 8                       No Sé
# 9                        Maze
# 10             Do What U Want
# 11                     G.U.Y.
# 12                    Spectre
# 13      Pongámonos De Acuerdo
# 14  Little Talks (Radio Edit)
# 15                      Gypsy
# 16                      Force
# 17                      Venus
# 18        She Bad (feat. Sj3)
# 19                     ARTPOP
# 20            Tere Sang Yaara
# 21                   Bring It
# 22            Show Me The Way
# 23                  Donatella
# 24               Sexxx Dreams
# 25          Batalla De Rutina
# 26                       None

# %%
test = df_spotify

# %%
# Fülle NaN-Werte in den Spalten 'track_name' und 'artist_name' von df_spotify mit den Werten aus merged_df
df_spotify['track_name'].fillna(merged_df['track_name'], inplace=True)
df_spotify['artist_name'].fillna(merged_df['artist_name'], inplace=True)
# Out:
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_8176/3362313963.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spotify['track_name'].fillna(merged_df['track_name'], inplace=True)
# /var/folders/g_/1j1nrg9s2j79cfcwpn2lrngr0000gn/T/ipykernel_8176/3362313963.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_spotify['artist_name'].fillna(merged_df['artist_name'], inplace=True)

# %%
df_spotify[df_spotify['artist_name'].isna() | df_spotify['track_name'].isna()]
# Out:
# Empty DataFrame
# Columns: [track_uri, artist_name, track_name]
# Index: []

# %%
df_spotify[df_spotify.track_uri == 'spotify:track:41AioelS7TlDckavuvL4fs']
# Out:
#                                   track_uri      artist_name track_name
# 14512  spotify:track:41AioelS7TlDckavuvL4fs  Tariq Da Hustla       Maze

# %%
df_spotify.to_csv('spotify_no_null.csv', index=False)

# %%
df_clean = pd.read_csv('spotify_no_null.csv')

# %%
#Show all NaN Rows
nan_rows = df_clean[df_clean.isna().any(axis=1)]
print(nan_rows)
# Out:
#                                   track_uri        artist_name track_name
# 47663  spotify:track:7BGQCe62A58Q5ZgpQFX93t  Elevation Worship        NaN

# %%
#Put the NaN Rows back into the df
df_clean = pd.concat([df_clean, nan_rows], ignore_index=True)

# %%
df_clean = df_clean.dropna()

# %%
#Pattern Removal via RegEx
def remove_patterns(track_name):
    pattern = r'[-(](?=.*(?:live|remaster))[^)]*' 
    return re.sub(pattern, '', track_name).strip()

# Apply the function
df_clean['track_name'] = df_clean['track_name'].apply(remove_patterns)

# %%
#Defining a Function to delete stuff with RegEx
def remove_after_remastered(track_name):
    if isinstance(track_name, str):
        pattern = r'(?i)-\s*remastered.*$'
        return re.sub(pattern, '', track_name)
    else:
        return track_name

#Apply the function
df_clean['track_name'] = df_clean['track_name'].apply(remove_after_remastered)

# %%
#Defining a function to delete more stuff with RegEx
def remove_after_radio(track_name):
    if isinstance(track_name, str):
        pattern = r'(?i)-\s*radio.*$'
        return re.sub(pattern, '', track_name)
    else:
        return track_name

#Apply Function
df_clean['track_name'] = df_clean['track_name'].apply(remove_after_radio)

# %%
df_clean.to_csv('clean_spotify3.csv', index=False)
